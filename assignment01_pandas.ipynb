# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению
# <center>
# Автор материала: Юрий Кашницкий, программист-исследователь Mail.Ru Group <br>
#
# Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center>Домашнее задание № 1 (демо).<br> Анализ данных по доходу населения UCI Adult</center>

# %% [markdown]
# **В задании предлагается с помощью Pandas ответить на несколько вопросов по данным репозитория UCI [Adult](https://archive.ics.uci.edu/ml/datasets/Adult) (качать данные не надо – они уже есть в репозитории). Для отправки решений используйте [онлайн-форму](https://docs.google.com/forms/d/1xAzU-5N6oEeR4UG8G44V6XL-Kbr4WYcPBG45Kijge2Y).**

# %% [markdown]
# Уникальные значения признаков (больше информации по ссылке выше):
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - salary: >50K,<=50K

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('adult.data.csv')
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# **1. Сколько мужчин и женщин (признак *sex*) представлено в этом наборе данных?**

# %%
len(data[data['sex']=='Female']),len(data[data['sex']=='Male'])
# Out:
# (10771, 21790)

# %% [markdown]
# **2. Каков средний возраст (признак *age*) женщин?**

# %%
data[data['sex']=='Female']['age'].mean()
# Out:
# 36.85823043357163

# %% [markdown]
# **3. Какова доля граждан Германии (признак *native-country*)?**

# %%
len(data[data['native-country']=='Germany'])/len(data)*100
# Out:
# 0.42074874850281013

# %% [markdown]
# **4-5. Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год? **

# %%
data[data['salary']>'<=50k']['age'].mean(),data[data['salary']>'<=50k']['age'].std(),\
data[data['salary']<'<=50k']['age'].mean(),data[data['salary']<'<=50k']['age'].std()


data.groupby(["salary"])["age"].agg([np.mean, np.std])
# Out:
#              mean        std
# salary
# <=50K   36.783738  14.020088
# >50K    44.249841  10.519028

# %% [markdown]
# **6. Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* или *Doctorate*)**

# %%
data[(data['salary']>'<=50k')&(data['education']=='HS-grad')]
# Out:
#        age         workclass  fnlwgt education  education-num  \
# 7       52  Self-emp-not-inc  209642   HS-grad              9
# 67      53           Private  169846   HS-grad              9
# 84      44           Private  343591   HS-grad              9
# 86      49         Local-gov  268234   HS-grad              9
# 105     32      Self-emp-inc  317660   HS-grad              9
# 112     56  Self-emp-not-inc  335605   HS-grad              9
# 154     52                 ?  252903   HS-grad              9
# 208     58      Self-emp-inc  210563   HS-grad              9
# 211     37           Private  208358   HS-grad              9
# 246     58           Private  236596   HS-grad              9
# 255     42  Self-emp-not-inc  303044   HS-grad              9
# 267     64           Private   21174   HS-grad              9
# 269     33           Private  222205   HS-grad              9
# 270     61           Private   69867   HS-grad              9
# 302     31           Private  217460   HS-grad              9
# 303     55           Private  238638   HS-grad              9
# 342     36         State-gov  119272   HS-grad              9
# 355     38       Federal-gov   95432   HS-grad              9
# 390     35           Private  220098   HS-grad              9
# 428     63      Self-emp-inc  222289   HS-grad              9
# 452     60           Private  245062   HS-grad              9
# 454     44  Self-emp-not-inc  234885   HS-grad              9
# 521     50           Private  196232   HS-grad              9
# 581     57           Private   69884   HS-grad              9
# 626     34           Private  153614   HS-grad              9
# 659     43           Private  174524   HS-grad              9
# 667     42           Private  247019   HS-grad              9
# 674     50      Self-emp-inc  219420   HS-grad              9
# 682     34  Self-emp-not-inc  190290   HS-grad              9
# 723     50         Local-gov   50459   HS-grad              9
# ...    ...               ...     ...       ...            ...
# 31939   41           Private  117585   HS-grad              9
# 31958   45           Private  187901   HS-grad              9
# 31968   43         Local-gov  161240   HS-grad              9
# 31978   41           Private   29762   HS-grad              9
# 31992   45           Private  172822   HS-grad              9
# 32005   39           Private  128392   HS-grad              9
# 32016   62                 ?  178764   HS-grad              9
# 32024   53           Private   36327   HS-grad              9
# 32067   37  Self-emp-not-inc  126675   HS-grad              9
# 32098   45           Private  170871   HS-grad              9
# 32115   29           Private  119359   HS-grad              9
# 32117   47           Private  121124   HS-grad              9
# 32125   55           Private  165881   HS-grad              9
# 32133   52       Federal-gov  154521   HS-grad              9
# 32135   48           Private  175070   HS-grad              9
# 32161   37           Private  143771   HS-grad              9
# 32195   41           Private  112283   HS-grad              9
# 32216   45           Private  265097   HS-grad              9
# 32221   37  Self-emp-not-inc  162834   HS-grad              9
# 32234   41           Private  206139   HS-grad              9
# 32297   47           Private  160474   HS-grad              9
# 32302   45         Local-gov  162187   HS-grad              9
# 32375   59           Private  395736   HS-grad              9
# 32386   59       Federal-gov   23789   HS-grad              9
# 32415   57  Self-emp-not-inc   65080   HS-grad              9
# 32462   48      Self-emp-inc  185041   HS-grad              9
# 32510   39           Private  107302   HS-grad              9
# 32518   57         Local-gov  110417   HS-grad              9
# 32557   40           Private  154374   HS-grad              9
# 32560   52      Self-emp-inc  287927   HS-grad              9
#
#            marital-status         occupation   relationship  \
# 7      Married-civ-spouse    Exec-managerial        Husband
# 67     Married-civ-spouse       Adm-clerical           Wife
# 84               Divorced       Craft-repair  Not-in-family
# 86     Married-civ-spouse    Protective-serv        Husband
# 105    Married-civ-spouse       Craft-repair        Husband
# 112    Married-civ-spouse      Other-service        Husband
# 154              Divorced                  ?  Not-in-family
# 208    Married-civ-spouse              Sales           Wife
# 211    Married-civ-spouse       Craft-repair        Husband
# 246    Married-civ-spouse       Adm-clerical        Husband
# 255    Married-civ-spouse    Farming-fishing        Husband
# 267    Married-civ-spouse    Exec-managerial        Husband
# 269    Married-civ-spouse       Craft-repair           Wife
# 270    Married-civ-spouse    Exec-managerial        Husband
# 302    Married-civ-spouse   Transport-moving        Husband
# 303    Married-civ-spouse              Sales        Husband
# 342    Married-civ-spouse    Protective-serv        Husband
# 355    Married-civ-spouse       Adm-clerical        Husband
# 390    Married-civ-spouse      Other-service           Wife
# 428    Married-civ-spouse    Exec-managerial        Husband
# 452    Married-civ-spouse       Craft-repair        Husband
# 454    Married-civ-spouse              Sales           Wife
# 521    Married-civ-spouse    Exec-managerial        Husband
# 581    Married-civ-spouse              Sales        Husband
# 626    Married-civ-spouse              Sales        Husband
# 659    Married-civ-spouse  Machine-op-inspct        Husband
# 667    Married-civ-spouse       Craft-repair        Husband
# 674    Married-civ-spouse              Sales        Husband
# 682    Married-civ-spouse       Craft-repair        Husband
# 723    Married-civ-spouse    Exec-managerial        Husband
# ...                   ...                ...            ...
# 31939  Married-civ-spouse    Exec-managerial        Husband
# 31958            Divorced    Farming-fishing  Not-in-family
# 31968  Married-civ-spouse    Protective-serv        Husband
# 31978  Married-civ-spouse       Craft-repair        Husband
# 31992  Married-civ-spouse  Machine-op-inspct        Husband
# 32005  Married-civ-spouse  Machine-op-inspct        Husband
# 32415               White    Male             0             0              50
# 32462               White    Male          7298             0              50
# 32510               White    Male             0             0              45
# 32518               White    Male         99999             0              40
# 32557               White    Male             0             0              40
# 32560               White  Female         15024             0              40
#
#       native-country salary
# 7      United-States   >50K
# 67     United-States   >50K
# 84     United-States   >50K
# 86     United-States   >50K
# 105    United-States   >50K
# 112           Canada   >50K
# 154    United-States   >50K
# 208    United-States   >50K
# 211    United-States   >50K
# 246    United-States   >50K
# 255         Cambodia   >50K
# 267    United-States   >50K
# 269    United-States   >50K
# 270    United-States   >50K
# 302    United-States   >50K
# 303    United-States   >50K
# 342    United-States   >50K
# 355    United-States   >50K
# 390    United-States   >50K
# 428    United-States   >50K
# 452    United-States   >50K
# 454    United-States   >50K
# 521    United-States   >50K
# 581    United-States   >50K
# 626    United-States   >50K
# 659    United-States   >50K
# 667    United-States   >50K
# 674    United-States   >50K
# 682    United-States   >50K
# 723    United-States   >50K
# ...              ...    ...
# 31939  United-States   >50K
# 31958  United-States   >50K
# 31968  United-States   >50K
# 31978  United-States   >50K
# 31992  United-States   >50K
# 32005  United-States   >50K
# 32016  United-States   >50K
# 32024  United-States   >50K
# 32067  United-States   >50K
# 32098  United-States   >50K
# 32115          China   >50K
# 32117  United-States   >50K
# 32125  United-States   >50K
# 32133  United-States   >50K
# 32135  United-States   >50K
# 32161  United-States   >50K
# 32195  United-States   >50K
# 32216  United-States   >50K
# 32221  United-States   >50K
# 32234  United-States   >50K
# 32297  United-States   >50K
# 32302  United-States   >50K
# 32375  United-States   >50K
# 32386  United-States   >50K
# 32415  United-States   >50K
# 32462  United-States   >50K
# 32510              ?   >50K
# 32518  United-States   >50K
# 32557  United-States   >50K
# 32560  United-States   >50K
#
# [1675 rows x 15 columns]

# %% [markdown]
# **7. Выведите статистику возраста для каждой расы (признак *race*) и каждого пола. Используйте *groupby* и *describe*. Найдите таким образом максимальный возраст мужчин расы *Amer-Indian-Eskimo*.**

# %%
data.groupby('age')[['race','sex']].describe()
data[(data['race']=='Amer-Indian-Eskimo')&(data['sex']=='Male')]['age'].max()
# Out:
# 82

# %% [markdown]
# **8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак *marital-status*)? Женатыми считаем тех, у кого *marital-status* начинается с *Married* (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**

# %%
rich = data[data["salary"] == ">50K"]

rich_married = len(rich[rich["marital-status"].str.startswith("Married")])#.shape[0]
rich_single = len(rich) - rich_married

if rich_married > rich_single:
    print("Married")
else: 
    print("Single")
# Out:
# Married

# %% [markdown]
# **9. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?**

# %%
tmp=data[data['hours-per-week']==data['hours-per-week'].max()]

data['hours-per-week'].max(),len(tmp), len(tmp[tmp['salary']>'<=50k'])/len(tmp['salary'])
# Out:
# (99, 85, 0.29411764705882354)

# %% [markdown]
# **10. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
data[(data['salary']>'<=50k')&(data['native-country']=='Japan')]['hours-per-week'].mean(),\
data[(data['salary']<'<=50k')&(data['native-country']=='Japan')]['hours-per-week'].mean()
# Out:
# (47.958333333333336, 41.0)
